# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # Quantization condition
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.integrate as scint
nmx=1000
nn=5
a=0.15
x=np.linspace(0,np.pi,nmx)
n=np.linspace(1,nn,nn)
eval0=n*n/2.0
eval=np.zeros(nn,float)
def fint(ene):
    p = np.sqrt(2.0*ene-a*x*x)
    value=scint.trapezoid(p,x)
    return value

ene=0.75
for i in range(nn):
    while((i+1)*np.pi-fint(ene))>0.000001:
        ene=ene+0.00001
    eval[i]=ene 
    print("E0 and E1:", eval0[i], "and", eval [i])

plt.xlabel("n")
plt.ylabel(r"$E-E_0$")
plt.plot(n,eval-eval0,marker='o')
plt.show()
# Out:
# E0 and E1: 0.5 and 0.7782199999998716
# E0 and E1: 2.0 and 2.2530800000070714
# E0 and E1: 4.5 and 4.749489999990142
# E0 and E1: 8.0 and 8.248279999857687
# E0 and E1: 12.5 and 12.747719999687348

# %% [markdown]
# ![image.png](attachment:image.png)
